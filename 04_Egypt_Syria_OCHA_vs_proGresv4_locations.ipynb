# %% [markdown]
# # proGres v4 Data Quality Script

# %% [markdown]
# # Section 1: Setup / Import data

# %% [markdown]
# ## 1.1 Notebook setup

# %% [markdown]
# #### Import libraries needed

# %%
import numpy as np
import pandas as pd
import pickle
import datetime as datetime
import pyodbc
import urllib
import sqlalchemy
import requests
import time
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# ## 1.2 Import proGres v4 Individual and Location Level Tables

# %% [markdown]
# ### Connect to database

# %%
# text1 = ''
# text2 = ''
saveFile = open('pwd.txt', 'r+')
# saveFile.write(text1 + ',' + text2)
# saveFile.seek(0)
uap = saveFile.read()

# %%
ip_of_server = "**.***.**.**"
driver = 'SQL Server'
ip = ip_of_server
db_connection = pyodbc.connect(
    driver = driver,
    Server = ip,
    Port = "1433",
    Database = "QualityCheck_Egypt",
    UID = uap.split(',')[0],
    PWD = uap.split(',')[1])

# %%
# checking
pyodbc.drivers()
# Out:
# ['SQL Server']

# %%
# checking
type(db_connection)
# Out:
# pyodbc.Connection

# %% [markdown]
# ### 1.1.1 Import v4 Individual table

# %%
dfi = pd.read_sql_query("SELECT * FROM dbo.Filteredprogres_individual", db_connection)
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290220 entries, 0 to 290219
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   modifiedon                         290220 non-null  datetime64[ns]
#  1   createdon                          290220 non-null  datetime64[ns]
#  2   progres_registrationgroupidname    290220 non-null  object
#  3   progres_placeofbirthidname         290163 non-null  object
#  4   createdbyname                      290220 non-null  object
#  5   progres_indvidualid                290220 non-null  object
#  6   progres_sexname                    290220 non-null  object
#  7   progres_id                         290220 non-null  object
#  8   progres_religionidname             290213 non-null  object
#  9   progres_isdeceased                 290220 non-null  bool
#  10  modifiedbyname                     290220 non-null  object
#  11  statuscodename                     290220 non-null  object
#  12  progres_coolocationlevel1name      275032 non-null  object
#  13  progres_familyname                 290220 non-null  object
#  14  progres_fathersname                285626 non-null  object
#  15  progres_nationalitylookupname      290213 non-null  object
#  16  progres_registrationgroupid        290220 non-null  object
#  17  progres_countryoforiginid          290220 non-null  object
#  18  progres_maritalstatusname          290220 non-null  object
#  19  progres_coolocationlevel2name      197171 non-null  object
#  20  progres_registrationreason         290220 non-null  int64
#  21  progres_agecohortname              290220 non-null  object
#  22  progres_relationshiptofp           290218 non-null  object
#  23  progres_businessunit               290220 non-null  object
#  24  progres_registrationdate           290220 non-null  datetime64[ns]
#  25  progres_individualid               290220 non-null  object
#  26  progres_coalocationlevel1name      289867 non-null  object
#  27  progres_refugeestatuscategoryname  279150 non-null  object
#  28  progres_age                        290220 non-null  int64
#  29  progres_sex                        290220 non-null  int64
#  30  progres_biometricstatus            222761 non-null  object
#  31  progres_dateofbirth                290220 non-null  datetime64[ns]
#  32  progres_ethnicityidname            290138 non-null  object
#  33  progres_registrationreasonname     290220 non-null  object
#  34  progres_countryofasylumidname      290220 non-null  object
#  35  progres_coolocationlevel3name      70561 non-null   object
#  36  progres_givenname                  290215 non-null  object
#  37  progres_refugeestatus              290220 non-null  int64
#  38  progres_countryofasylumid          290220 non-null  object
#  39  progres_maritalstatus              290220 non-null  int64
#  40  statuscode                         290220 non-null  int64
#  41  progres_primaryphonenumber         271767 non-null  object
#  42  progres_coalocationlevel2name      288602 non-null  object
#  43  progres_coalocationlevel3name      3344 non-null    object
#  44  progres_businessunitname           290220 non-null  object
#  45  progres_arrivaldate                290220 non-null  datetime64[ns]
#  46  progres_refugeestatusname          290220 non-null  object
#  47  progres_relationshiptofpname       290218 non-null  object
#  48  progres_deceaseddate               7 non-null       datetime64[ns]
#  49  progres_countryoforiginidname      290220 non-null  object
#  50  progres_nationalitylookup          290213 non-null  object
#  51  progres_placeofbirthcity           287646 non-null  object
#  52  progres_fleddate                   289526 non-null  datetime64[ns]
#  53  progres_hasphoto                   290220 non-null  bool
#  54  progres_educationlevelname         288184 non-null  object
# dtypes: bool(2), datetime64[ns](7), int64(6), object(40)
# memory usage: 117.9+ MB

# %% [markdown]
# #### Filter for active and hold and Business Unit in MENA

# %%
dfi[["statuscode" , "statuscodename", "progres_individualid"]].groupby(["statuscode" , "statuscodename"], dropna=False).count()
# Out:
#                            progres_individualid
# statuscode statuscodename
# 1          Active          290178
# 125080000  Hold            42

# %%
# Filter for statuscode [1, 125080000] 
# which correspond to statuscodename [Active, Hold] respectively
dfi = dfi[dfi.statuscode.isin([1, 125080000])]
dfi.shape
# Out:
# (290220, 55)

# %%
# Only keep MENA business units

# %%
list_mena_bu = ['Mauritania - Bassikounou',
                'Mauritania - Urban',
                'Tunisia - CO',
                'Egypt - CO',
                'Lebanon - North',
                'Lebanon - BML',
                'Lebanon - South',
                'Lebanon - Bekaa',
                'Algeria - CO',
                'Iraq - CO',
                'Israel - CO',
                'Jordan - Camps',
                'Jordan - Urban',
                'Kuwait - CO',
                'Morocco - CO',
                'RO Riyadh',
                'Syria - CO',
                'UAE - CO']

# %%
# dfi[["progres_businessunit" , 
#      "progres_businessunitname", 
#      "progres_individualid"]].groupby(["progres_businessunit" , 
#                                        "progres_businessunitname"], dropna=False).count()

# %%
dfi = dfi[dfi.progres_businessunitname.isin(list_mena_bu)]
dfi.shape
# Out:
# (290220, 55)

# %% [markdown]
# #### Check for and remove any duplicated entries

# %%
dfi[dfi.duplicated(keep=False)].head()
# Out:
# Empty DataFrame
# Columns: [modifiedon, createdon, progres_registrationgroupidname, progres_placeofbirthidname, createdbyname, progres_indvidualid, progres_sexname, progres_id, progres_religionidname, progres_isdeceased, modifiedbyname, statuscodename, progres_coolocationlevel1name, progres_familyname, progres_fathersname, progres_nationalitylookupname, progres_registrationgroupid, progres_countryoforiginid, progres_maritalstatusname, progres_coolocationlevel2name, progres_registrationreason, progres_agecohortname, progres_relationshiptofp, progres_businessunit, progres_registrationdate, progres_individualid, progres_coalocationlevel1name, progres_refugeestatuscategoryname, progres_age, progres_sex, progres_biometricstatus, progres_dateofbirth, progres_ethnicityidname, progres_registrationreasonname, progres_countryofasylumidname, progres_coolocationlevel3name, progres_givenname, progres_refugeestatus, progres_countryofasylumid, progres_maritalstatus, statuscode, progres_primaryphonenumber, progres_coalocationlevel2name, progres_coalocationlevel3name, progres_businessunitname, progres_arrivaldate, progres_refugeestatusname, progres_relationshiptofpname, progres_deceaseddate, progres_countryoforiginidname, progres_nationalitylookup, progres_placeofbirthcity, progres_fleddate, progres_hasphoto, progres_educationlevelname]
# Index: []

# %% [markdown]
# ### 1.1.2 Import v4 Admin Location Levels Table

# %%
admin = pd.read_sql_query("SELECT * FROM dbo.Filteredprogres_locationlevel", db_connection)

# %%
admin.statuscodename.value_counts()
# Out:
# Active    442999
# Name: statuscodename, dtype: int64

# %%
# admin = admin[admin.statecodename=="Active"]
admin.shape
# Out:
# (442999, 41)

# %%
admin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442999 entries, 0 to 442998
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   createdby                     442999 non-null  object
#  1   createdbyname                 442999 non-null  object
#  2   createdbyyominame             442999 non-null  object
#  3   createdon                     442999 non-null  datetime64[ns]
#  4   createdonutc                  442999 non-null  datetime64[ns]
#  5   createdonbehalfby             0 non-null       object
#  6   createdonbehalfbyname         0 non-null       object
#  7   createdonbehalfbyyominame     0 non-null       object
#  8   importsequencenumber          165503 non-null  float64
#  9   modifiedby                    442999 non-null  object
#  10  modifiedbyname                442999 non-null  object
#  11  modifiedbyyominame            442999 non-null  object
#  12  modifiedon                    442999 non-null  datetime64[ns]
#  13  modifiedonutc                 442999 non-null  datetime64[ns]
#  14  modifiedonbehalfby            1357 non-null    object
#  15  modifiedonbehalfbyname        1357 non-null    object
#  16  modifiedonbehalfbyyominame    1357 non-null    object
#  17  organizationid                442999 non-null  object
#  18  organizationidname            442999 non-null  object
#  19  overriddencreatedon           153 non-null     datetime64[ns]
#  20  overriddencreatedonutc        153 non-null     datetime64[ns]
#  21  progres_code                  442900 non-null  object
#  22  progres_countryid             442706 non-null  object
#  23  progres_countryidname         442706 non-null  object
#  24  progres_description_1025      421805 non-null  object
#  25  progres_description_1036      422430 non-null  object
#  26  progres_description_3082      423523 non-null  object
#  27  progres_filtercode            442889 non-null  object
#  28  progres_level                 442939 non-null  float64
#  29  progres_locationlevel         442939 non-null  object
#  30  progres_locationlevelid       442999 non-null  object
#  31  progres_originalalphabetname  49808 non-null   object
#  32  progres_parentlevelid         439418 non-null  object
#  33  progres_parentlevelidname     439418 non-null  object
#  34  statecode                     442999 non-null  int64
#  35  statecodename                 442999 non-null  object
#  36  statuscode                    442999 non-null  int64
#  37  statuscodename                442999 non-null  object
#  38  timezoneruleversionnumber     153 non-null     float64
#  39  utcconversiontimezonecode     153 non-null     float64
#  40  versionnumber                 442999 non-null  object
# dtypes: datetime64[ns](6), float64(4), int64(2), object(29)
# memory usage: 138.6+ MB

# %%
admin = admin[(admin.progres_countryidname=="Egypt")|(admin.progres_countryidname=="Syrian Arab Republic")]\
        [[ 'progres_code',
       'progres_countryid', 'progres_countryidname',
       'progres_description_1025', 'progres_description_1036',
       'progres_description_3082', 'progres_filtercode', 'progres_level',
       'progres_locationlevel', 'progres_locationlevelid']]
admin.shape
# Out:
# (13599, 10)

# %%
# not sure if we should be using progres_filtercode or progres_code; they don't always match
# most of these are at level 4, one at level 3
admin[admin.progres_filtercode!=admin.progres_code].shape
# Out:
# (38, 10)

# %%
# ahmed
# record(s) at level 3 where the two pcode fields in v4 don't match
# Al Makhrim is a Level 2 and Level 3 Name but pcode here is wrong, in the OCHA list, the pcode is SY040600 (NOT SY040650 nor SY040660)
admin[(admin.progres_filtercode!=admin.progres_code)&
     (admin.progres_level==3)]
# Out:
#           progres_code                     progres_countryid  \
# 252167  21SYR004006060  67C3DB59-6D90-E111-B138-005056AC02A7
#
#        progres_countryidname progres_description_1025  \
# 252167  Syrian Arab Republic  A_Al Makhrim
#
#        progres_description_1036 progres_description_3082 progres_filtercode  \
# 252167  F_Al Makhrim             S_Al Makhrim             21SYR004006050
#
#         progres_level progres_locationlevel  \
# 252167  3.0            Al Makhrim
#
#                      progres_locationlevelid
# 252167  F15D0D53-6F8F-EC11-8140-001DD8B71FE3

# %%
# ahmed
# record(s) at level 4 where the two pcode fields in v4 don't match
admin[(admin.progres_filtercode!=admin.progres_code)&
     (admin.progres_level==4)].head(2)
# Out:
#             progres_code                     progres_countryid  \
# 77334  21SYR001000008009  67C3DB59-6D90-E111-B138-005056AC02A7
# 77351  21SYR001000008010  67C3DB59-6D90-E111-B138-005056AC02A7
#
#       progres_countryidname progres_description_1025 progres_description_1036  \
# 77334  Syrian Arab Republic  A_Tabbaleh               F_Tabbaleh
# 77351  Syrian Arab Republic  A_Damascus City          F_Damascus City
#
#       progres_description_3082 progres_filtercode  progres_level  \
# 77334  S_Tabbaleh               21SYR001000008001  4.0
# 77351  S_Damascus City          21SYR001000008001  4.0
#
#       progres_locationlevel               progres_locationlevelid
# 77334  Tabbaleh              3EFF797F-718F-EC11-811F-00155D5CC4A0
# 77351  Damascus City         4FFF797F-718F-EC11-811F-00155D5CC4A0

# %%
admin[admin.progres_countryidname=="Egypt"].progres_level.value_counts()
# Out:
# 3.0    893
# 2.0    373
# 1.0    29
# Name: progres_level, dtype: int64

# %%
admin[admin.progres_countryidname=="Syrian Arab Republic"].progres_level.value_counts()
# Out:
# 4.0    6595
# 3.0    5633
# 2.0    62
# 1.0    14
# Name: progres_level, dtype: int64

# %%
admin["len_pcode_v1"] = admin["progres_code"].apply(lambda x: len(x))
admin["len_pcode_v2"] = admin["progres_filtercode"].apply(lambda x: len(x))
admin.groupby(["progres_level", "len_pcode_v1", "len_pcode_v2"]).progres_filtercode.count()
# Out:
# progres_level  len_pcode_v1  len_pcode_v2
# 1.0            6             6               1
#                8             8               42
# 2.0            11            11              435
# 3.0            14            14              6526
# 4.0            17            17              6595
# Name: progres_filtercode, dtype: int64

# %%
# ahmed
# There is one entry where the length of unhcr pcode is wrong so we'll omit this one
admin[(admin.len_pcode_v1==6)&(admin.progres_level==1)]
# Out:
#        progres_code                     progres_countryid  \
# 412042  EGY000       CFC1DB59-6D90-E111-B138-005056AC02A7
#
#        progres_countryidname progres_description_1025  \
# 412042  Egypt                 A_-
#
#        progres_description_1036 progres_description_3082 progres_filtercode  \
# 412042  F_-                      S_-                      EGY000
#
#         progres_level progres_locationlevel  \
# 412042  1.0            -
#
#                      progres_locationlevelid  len_pcode_v1  len_pcode_v2
# 412042  DCA29815-C25F-E711-80C5-001DD8B71FE4  6             6

# %%
# remove addresses at level 4 and those with UNCHR pcodes of length 6
admin = admin[(admin.len_pcode_v1!=6) & (admin.progres_level!=4)]

# %%
admin.loc[:,"len_pcode_v1"] = admin["progres_code"].apply(lambda x: len(x))
admin.loc[:,"len_pcode_v2"] = admin["progres_filtercode"].apply(lambda x: len(x))
admin.groupby(["progres_level", "len_pcode_v1", "len_pcode_v2"]).progres_filtercode.count()
# Out:
# progres_level  len_pcode_v1  len_pcode_v2
# 1.0            8             8               42
# 2.0            11            11              435
# 3.0            14            14              6526
# Name: progres_filtercode, dtype: int64

# %%
# Convert UNHCR pcodes to OCHA pcodes
admin.loc[:,"ocha_pcode"] = admin["progres_code"].apply(lambda x: x[2:4] + x[6:8] + x[9:11] + x[12:14] if len(x)==14  
                                                           else(x[2:4] + x[6:8] + x[9:11] if len(x)==11
                                                                else(x[2:4] + x[6:8])))

# %%
admin.loc[:,"len_pcode_ocha"] = admin["ocha_pcode"].apply(lambda x: len(x))
admin.groupby(["progres_level", "len_pcode_ocha"], dropna=False).progres_filtercode.count()
# Out:
# progres_level  len_pcode_ocha
# 1.0            4                 42
# 2.0            6                 435
# 3.0            8                 6526
# Name: progres_filtercode, dtype: int64

# %%
admin[admin.progres_countryidname=="Egypt"].progres_level.value_counts()
# Out:
# 3.0    893
# 2.0    373
# 1.0    28
# Name: progres_level, dtype: int64

# %%
admin[admin.progres_countryidname=="Syrian Arab Republic"].progres_level.value_counts()
# Out:
# 3.0    5633
# 2.0    62
# 1.0    14
# Name: progres_level, dtype: int64

# %%
admin[admin.progres_filtercode!=admin.progres_code]
# Out:
#           progres_code                     progres_countryid  \
# 252167  21SYR004006060  67C3DB59-6D90-E111-B138-005056AC02A7
#
#        progres_countryidname progres_description_1025  \
# 252167  Syrian Arab Republic  A_Al Makhrim
#
#        progres_description_1036 progres_description_3082 progres_filtercode  \
# 252167  F_Al Makhrim             S_Al Makhrim             21SYR004006050
#
#         progres_level progres_locationlevel  \
# 252167  3.0            Al Makhrim
#
#                      progres_locationlevelid  len_pcode_v1  len_pcode_v2  \
# 252167  F15D0D53-6F8F-EC11-8140-001DD8B71FE3  14            14
#
#        ocha_pcode  len_pcode_ocha
# 252167  SY040660   8

# %%
admin[admin.progres_level==1].sample(1)
# Out:
#        progres_code                     progres_countryid  \
# 299779  20EGY031     CFC1DB59-6D90-E111-B138-005056AC02A7
#
#        progres_countryidname progres_description_1025  \
# 299779  Egypt                 A_Red Sea
#
#        progres_description_1036 progres_description_3082 progres_filtercode  \
# 299779  F_Red Sea                S_Red Sea                20EGY031
#
#         progres_level progres_locationlevel  \
# 299779  1.0            Red Sea
#
#                      progres_locationlevelid  len_pcode_v1  len_pcode_v2  \
# 299779  B0F0AC72-E114-E911-80DE-001DD8B71FE4  8             8
#
#        ocha_pcode  len_pcode_ocha
# 299779  EG31       4

# %% [markdown]
# ## 1.3 Import official OCHA names for Egypt

# %%
# Source: https://data.humdata.org/dataset/cod-ab-egy # no location data provided so only taking admin3, admin2, and admin1 
egypt_ocha3 = pd.read_excel(r'egy_adminboundaries_tabulardata.xlsx', sheet_name='Admin3')
egypt_ocha2 = pd.read_excel(r'egy_adminboundaries_tabulardata.xlsx', sheet_name='Admin2')
egypt_ocha1 = pd.read_excel(r'egy_adminboundaries_tabulardata.xlsx', sheet_name='Admin1')

# %%
# Label admin levels and add extra column needed for joins with v4 data
egypt_ocha3["progres_level"] = 3
egypt_ocha3["ocha_pcode"] = egypt_ocha3["admin3Pcode"]
egypt_ocha2["progres_level"] = 2
egypt_ocha2["ocha_pcode"] = egypt_ocha2["admin2Pcode"]
egypt_ocha1["progres_level"] = 1
egypt_ocha1["ocha_pcode"] = egypt_ocha1["admin1Pcode"]
# concantenate data from levels 1 2 and 3
egypt_ocha = pd.concat([egypt_ocha3, egypt_ocha2, egypt_ocha1]).reset_index().drop(columns=["index"])

# %%
egypt_ocha.head(2)
# Out:
#    OBJECTID *  Shape * admin3Name_en admin3Name_ar admin3Pcode admin3RefName  \
# 0  1           Polygon  <Null>         الجزيره      EG120918    <Null>
# 1  2           Polygon  <Null>         الجهاد 4     EG240525    <Null>
#
#   admin3AltName1_en admin3AltName2_en admin3AltName1_ar admin3AltName2_ar  \
# 0  <Null>            <Null>            <Null>            <Null>
# 1  <Null>            <Null>            <Null>            <Null>
#
#    admin2Name_en admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar  \
# 0  Dikirnis       مركز دكرنس    EG1209      Dakahlia      الدقهلية
# 1  Markz Al Idwa  مركز العدوة   EG2405      Menia         المنيا
#
#   admin1Pcode admin0Name_en admin0Name_ar admin0Pcode       date    validOn  \
# 0  EG12        Egypt         مِصر          EG         2006-01-01 2017-04-21
# 1  EG24        Egypt         مِصر          EG         2006-01-01 2017-04-21
#
#   validTo  Shape_Length  Shape_Area  progres_level ocha_pcode admin2RefName  \
# 0  <Null>  0.055274      0.000157    3              EG120918   NaN
# 1  <Null>  0.101889      0.000594    3              EG240525   NaN
#
#   admin2AltName1_en admin2AltName2_en admin2AltName1_ar admin2AltName2_ar  \
# 0  NaN               NaN               NaN               NaN
# 1  NaN               NaN               NaN               NaN
#
#   ValidTo admin1RefName admin1AltName1_en admin1AltName2_en admin1AltName1_ar  \
# 0  NaN     NaN           NaN               NaN               NaN
# 1  NaN     NaN           NaN               NaN               NaN
#
#   admin1AltName2_ar
# 0  NaN
# 1  NaN

# %% [markdown]
# ## 1.4 Import official OCHA names for Syria

# %%
syria_ocha_loc = pd.read_excel(r'syr_humanitarian_locations_20200816.xlsx', sheet_name='Location')

# %%
# Source: https://data.humdata.org/dataset/cod-ab-syr
syria_ocha1 = pd.read_excel(r'syr_humanitarian_locations_20200816.xlsx', sheet_name='admin1')
syria_ocha2= pd.read_excel(r'syr_humanitarian_locations_20200816.xlsx', sheet_name='admin2')
syria_ocha3 = pd.read_excel(r'syr_humanitarian_locations_20200816.xlsx', sheet_name='admin3')
# add details on level and create new column to join with v4 on
syria_ocha3["progres_level"] = 3
syria_ocha3["ocha_pcode"] = syria_ocha3["admin3Pcode"]
syria_ocha2["progres_level"] = 2
syria_ocha2["ocha_pcode"] = syria_ocha2["admin2Pcode"]
syria_ocha1["progres_level"] = 1
syria_ocha1["ocha_pcode"] = syria_ocha1["admin1Pcode"]
# concantenate data from levels 1 2 and 3
syria_ocha = pd.concat([syria_ocha3, syria_ocha2, syria_ocha1]).reset_index().drop(columns=["index"])

# %%
syria_ocha.head(2)
# Out:
#           admin0Name_en              admin0Name_ar admin0Pcode admin1Name_en  \
# 0  Syrian Arab Republic  الجمهورية العربية السورية  SY          Idleb
# 1  Syrian Arab Republic  الجمهورية العربية السورية  SY          Idleb
#
#   admin1Name_ar admin1Pcode admin2Name_en admin2Name_ar admin2Pcode  \
# 0  إدلب          SY07        Ariha         أريحا         SY0705
# 1  إدلب          SY07        Ariha         أريحا         SY0705
#
#   admin3Name_en admin3Name_ar admin3Pcode admin3RefName_en LastUpdateDate  \
# 0  Ariha         مركز أريحا    SY070500    Ariha            2016-09-05
# 1  Ehsem         احسم          SY070501    Ehsem            2016-09-05
#
#       validOn  validTo  progres_level ocha_pcode admin2RefName admin1RefName
# 0  2016-09-05 NaN       3              SY070500   NaN           NaN
# 1  2016-09-05 NaN       3              SY070501   NaN           NaN

# %% [markdown]
# #### Compare between OCHA's location sheet (which exists only for Syria) and the combined admin 1 2 3 list for OCHA

# %%
# pcodes that exist in OCHA combined list but not in OCHA's location level list
[ x for x in syria_ocha[syria_ocha.progres_level==3].ocha_pcode.unique().tolist()
 if x not in syria_ocha_loc.admin3Pcode.unique().tolist()]
# Out:
# ['SY140201', 'SY140003']

# %%
# pcodes that exist in OCHA combined list but not in location level list
[ x for x in syria_ocha[syria_ocha.progres_level==2].ocha_pcode.unique().tolist()
 if x not in syria_ocha_loc.admin2Pcode.unique().tolist()]
# Out:
# []

# %%
# pcodes that exist in OCHA combined list but not in location level list
[ x for x in syria_ocha[syria_ocha.progres_level==1].ocha_pcode.unique().tolist()
 if x not in syria_ocha_loc.admin1Pcode.unique().tolist()]
# Out:
# []

# %%
# ahmed kaleem
# Example: these two exist in levels sheets of ocha spreadsheet but not the location list
syria_ocha[syria_ocha.ocha_pcode.isin(['SY140201', 'SY140003'])]
# Out:
#            admin0Name_en              admin0Name_ar admin0Pcode admin1Name_en  \
# 65  Syrian Arab Republic  الجمهورية العربية السورية  SY          Quneitra
# 69  Syrian Arab Republic  الجمهورية العربية السورية  SY          Quneitra
#
#    admin1Name_ar admin1Pcode admin2Name_en  admin2Name_ar admin2Pcode  \
# 65  القنيطرة      SY14        Al Fiq        فيق            SY1402
# 69  القنيطرة      SY14        Quneitra      مركز القنيطرة  SY1400
#
#    admin3Name_en admin3Name_ar admin3Pcode admin3RefName_en LastUpdateDate  \
# 65  Al-Butayhah   البطيحة       SY140201    Al-Butayhah      2016-09-05
# 69  Masaada       مسعدة         SY140003    Masaada          2016-09-05
#
#        validOn  validTo  progres_level ocha_pcode admin2RefName admin1RefName
# 65  2016-09-05 NaN       3              SY140201   NaN           NaN
# 69  2016-09-05 NaN       3              SY140003   NaN           NaN

# %%
syria_ocha_loc[syria_ocha_loc.admin3Pcode.isin(['SY140201', 'SY140003'])]
# Out:
# Empty DataFrame
# Columns: [admin0Name_en, admin0Name_ar, admin0Pcode, admin1Name_en, admin1Name_ar, admin1Pcode, admin2Name_en, admin2Name_ar, admin2Pcode, admin3Name_en, admin3Name_ar, admin3Pcode, admin4Name_en, admin4Name_ar, admin4Pcode, LocationName_en, LocationName_ar, Location_Pcode, location_type, LastUpdateDate, Latitude_y, Longitude_x]
# Index: []

# %%
# this means that the separate admin lists are more comprehensive than the location sheet in the OCHA list

# %%
[ x for x in syria_ocha_loc.admin1Pcode.unique().tolist()  if x not in syria_ocha[syria_ocha.progres_level==1].ocha_pcode.unique().tolist()]
# Out:
# []

# %%
[ x for x in syria_ocha_loc.admin2Pcode.unique().tolist()  if x not in syria_ocha[syria_ocha.progres_level==2].ocha_pcode.unique().tolist()]
# Out:
# []

# %%
[ x for x in syria_ocha_loc.admin3Pcode.unique().tolist()  if x not in syria_ocha[syria_ocha.progres_level==3].ocha_pcode.unique().tolist()]
# Out:
# []

# %% [markdown]
# # Section 2: Combine v4 data with OCHA data

# %%
# v4 location level data from Egypt
egypt_v4 = admin[admin.progres_countryidname=="Egypt"]
syria_v4 = admin[admin.progres_countryidname=="Syrian Arab Republic"]

# %%
# Merge v4 data with ocha data
# could do left join instead if we decide are only interested in the ocha list 
# that and will tag all other addresses as erroneous if their respective pcodes exist in v4 but not in ocha
egypt = pd.merge(egypt_v4, egypt_ocha, how="outer", on=["progres_level", "ocha_pcode"])
syria = pd.merge(syria_v4, syria_ocha, how="outer", on=["progres_level", "ocha_pcode"])

# %%
print("Egypt", egypt_ocha.shape, egypt_v4.shape, egypt.shape)
print("Syria", syria_ocha.shape, syria_v4.shape, syria.shape)
# Out:
# Egypt (6108, 37) (1294, 14) (6216, 49)
# Syria (348, 20) (5709, 14) (5746, 32)

# %% [markdown]
# ## 2.1 But first: Check between dfi table names and v4 location level table

# %%
# Lists of level 1 level 2 and level 3 addresses in the individual tables for Egypt and Syria 

eg1 = dfi[dfi.progres_countryofasylumidname=="Egypt"].progres_coalocationlevel1name.unique().tolist()
eg2 = dfi[dfi.progres_countryofasylumidname=="Egypt"].progres_coalocationlevel2name.unique().tolist()
eg3 = dfi[dfi.progres_countryofasylumidname=="Egypt"].progres_coalocationlevel3name.unique().tolist()

sy1 = dfi[dfi.progres_countryoforiginidname=="Syrian Arab Republic"].progres_coolocationlevel1name.unique().tolist()
sy2 = dfi[dfi.progres_countryoforiginidname=="Syrian Arab Republic"].progres_coolocationlevel3name.unique().tolist()
sy3 = dfi[dfi.progres_countryoforiginidname=="Syrian Arab Republic"].progres_coolocationlevel3name.unique().tolist()

# %% [markdown]
# ### Egypt: Are all names in dfi in v4 location level table?
# not many issues just Abu Durba in Egypt

# %%
# bad level 1
len([x for x in eg1 if x not in egypt[egypt.progres_level==1].progres_locationlevel.unique().tolist()])
# Out:
# 2

# %%
# bad level 1 details 
[x for x in eg1 if x not in egypt[egypt.progres_level==1].progres_locationlevel.unique().tolist()][:5]
# Out:
# [None, '-']

# %%
# good level 1
len([x for x in eg1 if x in egypt[egypt.progres_level==1].progres_locationlevel.unique().tolist()])
# Out:
# 27

# %%
# bad level 2
len([x for x in eg2 if x not in egypt[egypt.progres_level==2].progres_locationlevel.unique().tolist()])
# Out:
# 2

# %%
# bad level 2 details
# Because Abu Durba exists in the location level table at level 3, not 2! See below
[x for x in eg2 if x not in egypt[egypt.progres_level==2].progres_locationlevel.unique().tolist()]
# Out:
# [None, 'Abu Durba']

# %%
# ahmed
# this exists in dfi individual table at level 2 but not in the location levels table at level 2 (in location levels table, it's listed as a level 3 location)
# could this be because of open text field?
dfi[dfi.progres_coalocationlevel2name=="Abu Durba"][["progres_coalocationlevel1name",
                                                     "progres_coalocationlevel2name",
                                                     "progres_coalocationlevel3name"]]
# Out:
#        progres_coalocationlevel1name progres_coalocationlevel2name  \
# 14112   South Sinai                   Abu Durba
# 14114   South Sinai                   Abu Durba
# 14116   South Sinai                   Abu Durba
# 14118   South Sinai                   Abu Durba
# 17456   South Sinai                   Abu Durba
# 179218  South Sinai                   Abu Durba
# 205906  South Sinai                   Abu Durba
# 205909  South Sinai                   Abu Durba
# 205912  South Sinai                   Abu Durba
#
#        progres_coalocationlevel3name
# 14112   None
# 14114   None
# 14116   None
# 14118   None
# 17456   None
# 179218  None
# 205906  None
# 205909  None
# 205912  None

# %%
admin[admin.progres_locationlevel=="Abu Durba"].head()
# Out:
#           progres_code                     progres_countryid  \
# 323247  20EGY035001001  CFC1DB59-6D90-E111-B138-005056AC02A7
#
#        progres_countryidname progres_description_1025  \
# 323247  Egypt                 A_Abu Durba
#
#        progres_description_1036 progres_description_3082 progres_filtercode  \
# 323247  F_Abu Durba              S_Abu Durba              20EGY035001001
#
#         progres_level progres_locationlevel  \
# 323247  3.0            Abu Durba
#
#                      progres_locationlevelid  len_pcode_v1  len_pcode_v2  \
# 323247  74FAAC72-E114-E911-80DE-001DD8B71FE4  14            14
#
#        ocha_pcode  len_pcode_ocha
# 323247  EG350101   8

# %%
# good level 2
len([x for x in eg2 if x in egypt[egypt.progres_level==2].progres_locationlevel.unique().tolist()])
# Out:
# 283

# %%
# bad level 3 
len([x for x in eg3 if x not in egypt[egypt.progres_level==3].progres_locationlevel.unique().tolist()])
# Out:
# 1

# %%
# bad level 3 details
[x for x in eg3 if x not in egypt[egypt.progres_level==3].progres_locationlevel.unique().tolist()]
# Out:
# [None]

# %%
# good level 3
len([x for x in eg3 if x in egypt[egypt.progres_level==3].progres_locationlevel.unique().tolist()])
# Out:
# 75

# %% [markdown]
# ### Syria: Are all names in dfi in v4 location level table?
# More issues in Syria, including names that don't even exist in Syria are listed as location level 1

# %%
# bad level 1
len([x for x in sy1 if x not in syria[syria.progres_level==1].progres_locationlevel.unique().tolist()])
# Out:
# 11

# %%
# ahmed
# bad level 1 details
# names that don't even exist in Syria are listed as location level 1 : eg. Cairo, Baghdad, Khartoum etc.
[x for x in sy1 if x not in syria[syria.progres_level==1].progres_locationlevel.unique().tolist()][:12]
# Out:
# [None,
#  'Awdal',
#  'Al-hasakeh',
#  '-',
#  'Khartoum',
#  'North Kordofan',
#  'Tigray',
#  'Bursa',
#  'Cairo',
#  'Baghdad',
#  'Erbil']

# %%
# good level 1
len([x for x in sy1 if x in syria[syria.progres_level==1].progres_locationlevel.unique().tolist()])
# Out:
# 14

# %%
# ahmed
# bad level 2
# names must be typed up because we see Damascus (Joubar) ? 
[x for x in sy2 if x not in syria[syria.progres_level==2].progres_locationlevel.unique().tolist()][:15]
# Out:
# ['Babella',
#  None,
#  'El-maidaan',
#  'Hajar Aswad',
#  'Tadhamon',
#  'Damascus (Joubar)',
#  'Harasta',
#  'Jobar',
#  'El-shaghoor',
#  'Arbin',
#  'El-mazzeh',
#  'Masaken Barzeh',
#  'Sahnaya',
#  'Ein El-Bayda',
#  'Kisweh']

# %%
# bad level 2
len([x for x in sy2 if x not in syria[syria.progres_level==2].progres_locationlevel.unique().tolist()])
# Out:
# 155

# %%
# good level 2
len([x for x in sy2 if x in syria[syria.progres_level==2].progres_locationlevel.unique().tolist()])
# Out:
# 42

# %%
# bad level 3
len([x for x in sy3 if x not in syria[syria.progres_level==3].progres_locationlevel.unique().tolist()])
# Out:
# 1

# %%
# bad level 3
[x for x in sy3 if x not in syria[syria.progres_level==3].progres_locationlevel.unique().tolist()][:10]
# Out:
# [None]

# %%
# good level 3
len([x for x in sy3 if x in syria[syria.progres_level==3].progres_locationlevel.unique().tolist()])
# Out:
# 196

# %% [markdown]
# ##  2.2 Explore how many matched between v4 and ocha, how many didn't based on pcodes
# they didn't match because the pcodes didn't exist in the right table or didn't exist at all

# %% [markdown]
# #### Egypt issues with v4 and ocha matches

# %%
# pcodes that exist in OCHA but not in v4 (this is not so much of a problem? maybe people did not come from these locations?) 
egypt[(egypt.len_pcode_v1.isna())].shape
# Out:
# (4922, 49)

# %%
# pcodes that exist in OCHA but not in v4 (this is not so much of a problem? maybe people did not come from these locations?) 
egypt[egypt.len_pcode_v1.isna()].progres_level.value_counts()
# Out:
# 3.0    4921
# 2.0    1
# Name: progres_level, dtype: int64

# %%
# ahmed
# pcodes that exist in OCHA but not in v4 (this is not so much of a problem? maybe people did not come from these locations?) 
# Egypt "Halayib" with pcode EG3107
egypt[(egypt.len_pcode_v1.isna()) & (egypt.progres_level==2)]
# Out:
#      progres_code progres_countryid progres_countryidname  \
# 6215  NaN          NaN               NaN
#
#      progres_description_1025 progres_description_1036  \
# 6215  NaN                      NaN
#
#      progres_description_3082 progres_filtercode  progres_level  \
# 6215  NaN                      NaN                2.0
#
#      progres_locationlevel progres_locationlevelid  len_pcode_v1  \
# 6215  NaN                   NaN                    NaN
#
#       len_pcode_v2 ocha_pcode  len_pcode_ocha  OBJECTID *  Shape *  \
# 6215 NaN            EG3107    NaN              167.0       Polygon
#
#      admin3Name_en admin3Name_ar admin3Pcode admin3RefName admin3AltName1_en  \
# 6215  NaN           NaN           NaN         NaN           NaN
#
#      admin3AltName2_en admin3AltName1_ar admin3AltName2_ar admin2Name_en  \
# 6215  NaN               NaN               NaN               Halayib
#
#      admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 6215  قسم حلايب     EG3107      Red Sea       البحر الأحمر  EG31
#
#      admin0Name_en admin0Name_ar admin0Pcode       date    validOn validTo  \
# 6215  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
#
#       Shape_Length  Shape_Area admin2RefName admin2AltName1_en  \
# 6215  3.902031      0.662337    Halayib       <Null>
#
#      admin2AltName2_en admin2AltName1_ar admin2AltName2_ar ValidTo  \
# 6215  <Null>            <Null>            <Null>            <Null>
#
#      admin1RefName admin1AltName1_en admin1AltName2_en admin1AltName1_ar  \
# 6215  NaN           NaN               NaN               NaN
#
#      admin1AltName2_ar
# 6215  NaN

# %%
# egypt_v4[(egypt_v4.progres_level==2)&(egypt_v4.ocha_pcode=="EG3107")]

# %%
# pcodes that exist in  v4 but not in OCHA list
egypt[egypt.admin0Pcode.isna()].shape
# Out:
# (100, 49)

# %%
# pcodes that exist in v4 but not in OCHA
egypt[egypt.admin0Pcode.isna()].progres_level.value_counts()
# Out:
# 3.0    98
# 1.0    1
# 2.0    1
# Name: progres_level, dtype: int64

# %%
# ahmed
# pcodes that exist in v4 but not in OCHA
# This is a disputed admin2 location: Shallatin - Disputed
egypt[(egypt.admin0Pcode.isna()) &(egypt.progres_level==2)]
# Out:
#     progres_code                     progres_countryid progres_countryidname  \
# 400  20EGY040001  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
#
#     progres_description_1025 progres_description_1036  \
# 400  A_Shallatin - Disputed   F_Shallatin - Disputed
#
#     progres_description_3082 progres_filtercode  progres_level  \
# 400  S_Shallatin - Disputed   20EGY040001        2.0
#
#     progres_locationlevel               progres_locationlevelid  len_pcode_v1  \
# 400  Shallatin - Disputed  92F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
#
#      len_pcode_v2 ocha_pcode  len_pcode_ocha  OBJECTID * Shape *  \
# 400  11.0          EG4001     6.0            NaN          NaN
#
#     admin3Name_en admin3Name_ar admin3Pcode admin3RefName admin3AltName1_en  \
# 400  NaN           NaN           NaN         NaN           NaN
#
#     admin3AltName2_en admin3AltName1_ar admin3AltName2_ar admin2Name_en  \
# 400  NaN               NaN               NaN               NaN
#
#     admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 400  NaN           NaN         NaN           NaN           NaN
#
#     admin0Name_en admin0Name_ar admin0Pcode date validOn validTo  \
# 400  NaN           NaN           NaN        NaT  NaT      NaN
#
#      Shape_Length  Shape_Area admin2RefName admin2AltName1_en  \
# 400 NaN           NaN          NaN           NaN
#
#     admin2AltName2_en admin2AltName1_ar admin2AltName2_ar ValidTo  \
# 400  NaN               NaN               NaN               NaN
#
#     admin1RefName admin1AltName1_en admin1AltName2_en admin1AltName1_ar  \
# 400  NaN           NaN               NaN               NaN
#
#     admin1AltName2_ar
# 400  NaN

# %%
# ahmed
# pcodes that exist in v4 but not in OCHA
# This is a disputed admin1 location: Ma'tan al-Sarra - Disputed
egypt[(egypt.admin0Pcode.isna()) &(egypt.progres_level==1)]
# Out:
#    progres_code                     progres_countryid progres_countryidname  \
# 31  20EGY040     CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
#
#         progres_description_1025      progres_description_1036  \
# 31  A_Ma'tan al-Sarra - Disputed  F_Ma'tan al-Sarra - Disputed
#
#         progres_description_3082 progres_filtercode  progres_level  \
# 31  S_Ma'tan al-Sarra - Disputed  20EGY040           1.0
#
#          progres_locationlevel               progres_locationlevelid  \
# 31  Ma'tan al-Sarra - Disputed  A0F0AC72-E114-E911-80DE-001DD8B71FE4
#
#     len_pcode_v1  len_pcode_v2 ocha_pcode  len_pcode_ocha  OBJECTID * Shape *  \
# 31  8.0           8.0           EG40       4.0            NaN          NaN
#
#    admin3Name_en admin3Name_ar admin3Pcode admin3RefName admin3AltName1_en  \
# 31  NaN           NaN           NaN         NaN           NaN
#
#    admin3AltName2_en admin3AltName1_ar admin3AltName2_ar admin2Name_en  \
# 31  NaN               NaN               NaN               NaN
#
#    admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 31  NaN           NaN         NaN           NaN           NaN
#
#    admin0Name_en admin0Name_ar admin0Pcode date validOn validTo  Shape_Length  \
# 31  NaN           NaN           NaN        NaT  NaT      NaN    NaN
#
#     Shape_Area admin2RefName admin2AltName1_en admin2AltName2_en  \
# 31 NaN          NaN           NaN               NaN
#
#    admin2AltName1_ar admin2AltName2_ar ValidTo admin1RefName  \
# 31  NaN               NaN               NaN     NaN
#
#    admin1AltName1_en admin1AltName2_en admin1AltName1_ar admin1AltName2_ar
# 31  NaN               NaN               NaN               NaN

# %%
# ahmed
# pcodes that exist in v4 but not in OCHA

# Example: ocha_pcode EG250003 or EG240003	both at level 3 and names Al Itmaniyah and Gabal el Teir respectively did not exist in the OCHA list

# another example see for progres_level = 3: 
# EG020001 Kharj Al-Zamam and EG400101 Shallatin
# Kharj Al-Zamam doesn't exist in the OCHA list and
# Shallatin is at admin2 level in OCHA (EG3106) 
# egypt[egypt.admin0Pcode.isna()].iloc[:,24:].head(20)
egypt[egypt.admin0Pcode.isna()].head(20)
# Out:
#        progres_code                     progres_countryid  \
# 31   20EGY040        CFC1DB59-6D90-E111-B138-005056AC02A7
# 400  20EGY040001     CFC1DB59-6D90-E111-B138-005056AC02A7
# 438  20EGY002000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 524  20EGY040001001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 525  20EGY014000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 526  20EGY001000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 527  20EGY001000002  CFC1DB59-6D90-E111-B138-005056AC02A7
# 528  20EGY001000003  CFC1DB59-6D90-E111-B138-005056AC02A7
# 560  20EGY004005002  CFC1DB59-6D90-E111-B138-005056AC02A7
# 561  20EGY004005003  CFC1DB59-6D90-E111-B138-005056AC02A7
# 617  20EGY013000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 784  20EGY018000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 785  20EGY018000002  CFC1DB59-6D90-E111-B138-005056AC02A7
# 786  20EGY018000003  CFC1DB59-6D90-E111-B138-005056AC02A7
# 858  20EGY021000001  CFC1DB59-6D90-E111-B138-005056AC02A7
# 859  20EGY021000002  CFC1DB59-6D90-E111-B138-005056AC02A7
# 860  20EGY021000003  CFC1DB59-6D90-E111-B138-005056AC02A7
# 861  20EGY021000004  CFC1DB59-6D90-E111-B138-005056AC02A7
# 862  20EGY021000005  CFC1DB59-6D90-E111-B138-005056AC02A7
# 863  20EGY021000006  CFC1DB59-6D90-E111-B138-005056AC02A7
#
#     progres_countryidname        progres_description_1025  \
# 31   Egypt                 A_Ma'tan al-Sarra - Disputed
# 400  Egypt                 A_Shallatin - Disputed
# 438  Egypt                 A_Kharj Al-Zamam
# 524  Egypt                 A_Shallatin
# 525  Egypt                 A_Ezbet el-Insha
# 526  Egypt                 A_Ash Shabasiyah
# 527  Egypt                 A_Kafr ash Shara inah
# 528  Egypt                 A_Kafr Mas ud
# 560  Egypt                 A_Ezbet Farhan Eid
# 561  Egypt                 A_Ma diyah
# 617  Egypt                 A_Madinat al Ashir min Ramadan
# 784  Egypt                 A_Ash Shaghanibah
# 785  Egypt                 A_Bir Hooker
# 786  Egypt                 A_Bir Nasif
# 858  Egypt                 A_Al Hawariyah
# 859  Egypt                 A_Al Hayz
# 860  Egypt                 A_Al Uwaynah
# 861  Egypt                 A_Bawiti
# 862  Egypt                 A_El Harra
# 863  Egypt                 A_Ezbet Lambo
#
#            progres_description_1036        progres_description_3082  \
# 31   F_Ma'tan al-Sarra - Disputed    S_Ma'tan al-Sarra - Disputed
# 400  F_Shallatin - Disputed          S_Shallatin - Disputed
# 438  F_Kharj Al-Zamam                S_Kharj Al-Zamam
# 524  F_Shallatin                     S_Shallatin
# 525  F_Ezbet el-Insha                S_Ezbet el-Insha
# 526  F_Ash Shabasiyah                S_Ash Shabasiyah
# 527  F_Kafr ash Shara inah           S_Kafr ash Shara inah
# 528  F_Kafr Mas ud                   S_Kafr Mas ud
# 560  F_Ezbet Farhan Eid              S_Ezbet Farhan Eid
# 561  F_Ma diyah                      S_Ma diyah
# 617  F_Madinat al Ashir min Ramadan  S_Madinat al Ashir min Ramadan
# 784  F_Ash Shaghanibah               S_Ash Shaghanibah
# 785  F_Bir Hooker                    S_Bir Hooker
# 786  F_Bir Nasif                     S_Bir Nasif
# 858  F_Al Hawariyah                  S_Al Hawariyah
# 859  F_Al Hayz                       S_Al Hayz
# 860  F_Al Uwaynah                    S_Al Uwaynah
# 861  F_Bawiti                        S_Bawiti
# 862  F_El Harra                      S_El Harra
# 863  F_Ezbet Lambo                   S_Ezbet Lambo
#
#     progres_filtercode  progres_level         progres_locationlevel  \
# 31   20EGY040           1.0            Ma'tan al-Sarra - Disputed
# 400  20EGY040001        2.0            Shallatin - Disputed
# 438  20EGY002000001     3.0            Kharj Al-Zamam
# 524  20EGY040001001     3.0            Shallatin
# 525  20EGY014000001     3.0            Ezbet el-Insha
# 526  20EGY001000001     3.0            Ash Shabasiyah
# 527  20EGY001000002     3.0            Kafr ash Shara inah
# 528  20EGY001000003     3.0            Kafr Mas ud
# 560  20EGY004005002     3.0            Ezbet Farhan Eid
# 561  20EGY004005003     3.0            Ma diyah
# 617  20EGY013000001     3.0            Madinat al Ashir min Ramadan
# 784  20EGY018000001     3.0            Ash Shaghanibah
# 785  20EGY018000002     3.0            Bir Hooker
# 786  20EGY018000003     3.0            Bir Nasif
# 858  20EGY021000001     3.0            Al Hawariyah
# 859  20EGY021000002     3.0            Al Hayz
# 860  20EGY021000003     3.0            Al Uwaynah
# 861  20EGY021000004     3.0            Bawiti
# 862  20EGY021000005     3.0            El Harra
# 863  20EGY021000006     3.0            Ezbet Lambo
#
#                   progres_locationlevelid  len_pcode_v1  len_pcode_v2  \
# 31   A0F0AC72-E114-E911-80DE-001DD8B71FE4  8.0           8.0
# 400  92F3AC72-E114-E911-80DE-001DD8B71FE4  11.0          11.0
# 438  DEF3AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 524  8AF4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 525  8CF4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 526  8EF4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 527  90F4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 528  92F4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 560  D2F4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 561  D4F4AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 617  44F5AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 784  92F6AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 785  94F6AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 786  96F6AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 858  26F7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 859  28F7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 860  2AF7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 861  2CF7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 862  2EF7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
# 863  30F7AC72-E114-E911-80DE-001DD8B71FE4  14.0          14.0
#
#     ocha_pcode  len_pcode_ocha  OBJECTID * Shape * admin3Name_en  \
# 31   EG40       4.0            NaN          NaN     NaN
# 400  EG4001     6.0            NaN          NaN     NaN
# 438  EG020001   8.0            NaN          NaN     NaN
# 524  EG400101   8.0            NaN          NaN     NaN
# 525  EG140001   8.0            NaN          NaN     NaN
# 526  EG010001   8.0            NaN          NaN     NaN
# 527  EG010002   8.0            NaN          NaN     NaN
# 528  EG010003   8.0            NaN          NaN     NaN
# 560  EG040502   8.0            NaN          NaN     NaN
# 561  EG040503   8.0            NaN          NaN     NaN
# 617  EG130001   8.0            NaN          NaN     NaN
# 784  EG180001   8.0            NaN          NaN     NaN
# 785  EG180002   8.0            NaN          NaN     NaN
# 786  EG180003   8.0            NaN          NaN     NaN
# 858  EG210001   8.0            NaN          NaN     NaN
# 859  EG210002   8.0            NaN          NaN     NaN
# 860  EG210003   8.0            NaN          NaN     NaN
# 861  EG210004   8.0            NaN          NaN     NaN
# 862  EG210005   8.0            NaN          NaN     NaN
# 863  EG210006   8.0            NaN          NaN     NaN
#
#     admin3Name_ar admin3Pcode admin3RefName admin3AltName1_en  \
# 31   NaN           NaN         NaN           NaN
# 400  NaN           NaN         NaN           NaN
# 438  NaN           NaN         NaN           NaN
# 524  NaN           NaN         NaN           NaN
# 525  NaN           NaN         NaN           NaN
# 526  NaN           NaN         NaN           NaN
# 527  NaN           NaN         NaN           NaN
# 528  NaN           NaN         NaN           NaN
# 560  NaN           NaN         NaN           NaN
# 561  NaN           NaN         NaN           NaN
# 617  NaN           NaN         NaN           NaN
# 784  NaN           NaN         NaN           NaN
# 785  NaN           NaN         NaN           NaN
# 786  NaN           NaN         NaN           NaN
# 858  NaN           NaN         NaN           NaN
# 859  NaN           NaN         NaN           NaN
# 860  NaN           NaN         NaN           NaN
# 861  NaN           NaN         NaN           NaN
# 862  NaN           NaN         NaN           NaN
# 863  NaN           NaN         NaN           NaN
#
#     admin3AltName2_en admin3AltName1_ar admin3AltName2_ar admin2Name_en  \
# 31   NaN               NaN               NaN               NaN
# 400  NaN               NaN               NaN               NaN
# 438  NaN               NaN               NaN               NaN
# 524  NaN               NaN               NaN               NaN
# 525  NaN               NaN               NaN               NaN
# 526  NaN               NaN               NaN               NaN
# 527  NaN               NaN               NaN               NaN
# 528  NaN               NaN               NaN               NaN
# 560  NaN               NaN               NaN               NaN
# 561  NaN               NaN               NaN               NaN
# 617  NaN               NaN               NaN               NaN
# 784  NaN               NaN               NaN               NaN
# 785  NaN               NaN               NaN               NaN
# 786  NaN               NaN               NaN               NaN
# 858  NaN               NaN               NaN               NaN
# 859  NaN               NaN               NaN               NaN
# 860  NaN               NaN               NaN               NaN
# 861  NaN               NaN               NaN               NaN
# 862  NaN               NaN               NaN               NaN
# 863  NaN               NaN               NaN               NaN
#
#     admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 31   NaN           NaN         NaN           NaN           NaN
# 400  NaN           NaN         NaN           NaN           NaN
# 438  NaN           NaN         NaN           NaN           NaN
# 524  NaN           NaN         NaN           NaN           NaN
# 525  NaN           NaN         NaN           NaN           NaN
# 526  NaN           NaN         NaN           NaN           NaN
# 527  NaN           NaN         NaN           NaN           NaN
# 528  NaN           NaN         NaN           NaN           NaN
# 560  NaN           NaN         NaN           NaN           NaN
# 561  NaN           NaN         NaN           NaN           NaN
# 617  NaN           NaN         NaN           NaN           NaN
# 784  NaN           NaN         NaN           NaN           NaN
# 785  NaN           NaN         NaN           NaN           NaN
# 786  NaN           NaN         NaN           NaN           NaN
# 858  NaN           NaN         NaN           NaN           NaN
# 859  NaN           NaN         NaN           NaN           NaN
# 860  NaN           NaN         NaN           NaN           NaN
# 861  NaN           NaN         NaN           NaN           NaN
# 862  NaN           NaN         NaN           NaN           NaN
# 863  NaN           NaN         NaN           NaN           NaN
#
#     admin0Name_en admin0Name_ar admin0Pcode date validOn validTo  \
# 31   NaN           NaN           NaN        NaT  NaT      NaN
# 400  NaN           NaN           NaN        NaT  NaT      NaN
# 438  NaN           NaN           NaN        NaT  NaT      NaN
# 524  NaN           NaN           NaN        NaT  NaT      NaN
# 525  NaN           NaN           NaN        NaT  NaT      NaN
# 526  NaN           NaN           NaN        NaT  NaT      NaN
# 527  NaN           NaN           NaN        NaT  NaT      NaN
# 528  NaN           NaN           NaN        NaT  NaT      NaN
# 560  NaN           NaN           NaN        NaT  NaT      NaN
# 561  NaN           NaN           NaN        NaT  NaT      NaN
# 617  NaN           NaN           NaN        NaT  NaT      NaN
# 784  NaN           NaN           NaN        NaT  NaT      NaN
# 785  NaN           NaN           NaN        NaT  NaT      NaN
# 786  NaN           NaN           NaN        NaT  NaT      NaN
# 858  NaN           NaN           NaN        NaT  NaT      NaN
# 859  NaN           NaN           NaN        NaT  NaT      NaN
# 860  NaN           NaN           NaN        NaT  NaT      NaN
# 861  NaN           NaN           NaN        NaT  NaT      NaN
# 862  NaN           NaN           NaN        NaT  NaT      NaN
# 863  NaN           NaN           NaN        NaT  NaT      NaN
#
#      Shape_Length  Shape_Area admin2RefName admin2AltName1_en  \
# 31  NaN           NaN          NaN           NaN
# 400 NaN           NaN          NaN           NaN
# 438 NaN           NaN          NaN           NaN
# 524 NaN           NaN          NaN           NaN
# 525 NaN           NaN          NaN           NaN
# 526 NaN           NaN          NaN           NaN
# 527 NaN           NaN          NaN           NaN
# 528 NaN           NaN          NaN           NaN
# 560 NaN           NaN          NaN           NaN
# 561 NaN           NaN          NaN           NaN
# 617 NaN           NaN          NaN           NaN
# 784 NaN           NaN          NaN           NaN
# 785 NaN           NaN          NaN           NaN
# 786 NaN           NaN          NaN           NaN
# 858 NaN           NaN          NaN           NaN
# 859 NaN           NaN          NaN           NaN
# 860 NaN           NaN          NaN           NaN
# 861 NaN           NaN          NaN           NaN
# 862 NaN           NaN          NaN           NaN
# 863 NaN           NaN          NaN           NaN
#
#     admin2AltName2_en admin2AltName1_ar admin2AltName2_ar ValidTo  \
# 31   NaN               NaN               NaN               NaN
# 400  NaN               NaN               NaN               NaN
# 438  NaN               NaN               NaN               NaN
# 524  NaN               NaN               NaN               NaN
# 525  NaN               NaN               NaN               NaN
# 526  NaN               NaN               NaN               NaN
# 527  NaN               NaN               NaN               NaN
# 528  NaN               NaN               NaN               NaN
# 560  NaN               NaN               NaN               NaN
# 561  NaN               NaN               NaN               NaN
# 617  NaN               NaN               NaN               NaN
# 784  NaN               NaN               NaN               NaN
# 785  NaN               NaN               NaN               NaN
# 786  NaN               NaN               NaN               NaN
# 858  NaN               NaN               NaN               NaN
# 859  NaN               NaN               NaN               NaN
# 860  NaN               NaN               NaN               NaN
# 861  NaN               NaN               NaN               NaN
# 862  NaN               NaN               NaN               NaN
# 863  NaN               NaN               NaN               NaN
#
#     admin1RefName admin1AltName1_en admin1AltName2_en admin1AltName1_ar  \
# 31   NaN           NaN               NaN               NaN
# 400  NaN           NaN               NaN               NaN
# 438  NaN           NaN               NaN               NaN
# 524  NaN           NaN               NaN               NaN
# 525  NaN           NaN               NaN               NaN
# 526  NaN           NaN               NaN               NaN
# 527  NaN           NaN               NaN               NaN
# 528  NaN           NaN               NaN               NaN
# 560  NaN           NaN               NaN               NaN
# 561  NaN           NaN               NaN               NaN
# 617  NaN           NaN               NaN               NaN
# 784  NaN           NaN               NaN               NaN
# 785  NaN           NaN               NaN               NaN
# 786  NaN           NaN               NaN               NaN
# 858  NaN           NaN               NaN               NaN
# 859  NaN           NaN               NaN               NaN
# 860  NaN           NaN               NaN               NaN
# 861  NaN           NaN               NaN               NaN
# 862  NaN           NaN               NaN               NaN
# 863  NaN           NaN               NaN               NaN
#
#     admin1AltName2_ar
# 31   NaN
# 400  NaN
# 438  NaN
# 524  NaN
# 525  NaN
# 526  NaN
# 527  NaN
# 528  NaN
# 560  NaN
# 561  NaN
# 617  NaN
# 784  NaN
# 785  NaN
# 786  NaN
# 858  NaN
# 859  NaN
# 860  NaN
# 861  NaN
# 862  NaN
# 863  NaN

# %% [markdown]
# #### Syria issues with v4 and ocha matches

# %%
# pcodes that exist in OCHA but not in v4 (this is not so much of a problem? maybe people did not come from these locations?) 
syria[syria.len_pcode_v1.isna()].shape
# Out:
# (37, 32)

# %%
# ahmed 
# pcodes that exist in OCHA but not in v4
syria[syria.len_pcode_v1.isna()].head()
# Out:
#      progres_code progres_countryid progres_countryidname  \
# 5709  NaN          NaN               NaN
# 5710  NaN          NaN               NaN
# 5711  NaN          NaN               NaN
# 5712  NaN          NaN               NaN
# 5713  NaN          NaN               NaN
#
#      progres_description_1025 progres_description_1036  \
# 5709  NaN                      NaN
# 5710  NaN                      NaN
# 5711  NaN                      NaN
# 5712  NaN                      NaN
# 5713  NaN                      NaN
#
#      progres_description_3082 progres_filtercode  progres_level  \
# 5709  NaN                      NaN                3.0
# 5710  NaN                      NaN                3.0
# 5711  NaN                      NaN                3.0
# 5712  NaN                      NaN                3.0
# 5713  NaN                      NaN                3.0
#
#      progres_locationlevel progres_locationlevelid  len_pcode_v1  \
# 5709  NaN                   NaN                    NaN
# 5710  NaN                   NaN                    NaN
# 5711  NaN                   NaN                    NaN
# 5712  NaN                   NaN                    NaN
# 5713  NaN                   NaN                    NaN
#
#       len_pcode_v2 ocha_pcode  len_pcode_ocha         admin0Name_en  \
# 5709 NaN            SY070500  NaN              Syrian Arab Republic
# 5710 NaN            SY070400  NaN              Syrian Arab Republic
# 5711 NaN            SY070300  NaN              Syrian Arab Republic
# 5712 NaN            SY110300  NaN              Syrian Arab Republic
# 5713 NaN            SY130300  NaN              Syrian Arab Republic
#
#                   admin0Name_ar admin0Pcode admin1Name_en admin1Name_ar  \
# 5709  الجمهورية العربية السورية  SY          Idleb         إدلب
# 5710  الجمهورية العربية السورية  SY          Idleb         إدلب
# 5711  الجمهورية العربية السورية  SY          Idleb         إدلب
# 5712  الجمهورية العربية السورية  SY          Ar-Raqqa      الرقة
# 5713  الجمهورية العربية السورية  SY          As-Sweida     السويداء
#
#      admin1Pcode    admin2Name_en admin2Name_ar admin2Pcode    admin3Name_en  \
# 5709  SY07        Ariha            أريحا         SY0705      Ariha
# 5710  SY07        Jisr-Ash-Shugur  جسر الشغور    SY0704      Jisr-Ash-Shugur
# 5711  SY07        Harim            حارم          SY0703      Harim
# 5712  SY11        Ath-Thawrah      الثورة        SY1103      Al-Thawrah
# 5713  SY13        Shahba           شهبا          SY1303      Shahba
#
#         admin3Name_ar admin3Pcode admin3RefName_en LastUpdateDate     validOn  \
# 5709  مركز أريحا       SY070500    Ariha            2016-09-05     2016-09-05
# 5710  مركز جسر الشغور  SY070400    Jisr-Ash-Shugur  2016-09-05     2016-09-05
# 5711  مركز حارم        SY070300    Harim            2016-09-05     2016-09-05
# 5712  مركز الثورة      SY110300    Al-Thawrah       2016-09-05     2016-09-05
# 5713  مركز شهبا        SY130300    Shahba           2016-09-05     2016-09-05
#
#       validTo admin2RefName admin1RefName
# 5709 NaN       NaN           NaN
# 5710 NaN       NaN           NaN
# 5711 NaN       NaN           NaN
# 5712 NaN       NaN           NaN
# 5713 NaN       NaN           NaN

# %%
# pcodes that exist in OCHA but not in v4
syria[syria.len_pcode_v1.isna()].progres_level.value_counts()
# Out:
# 3.0    37
# Name: progres_level, dtype: int64

# %%
# pcodes that exist in v4 but not in the OCHA list
syria[syria.admin0Pcode.isna()].shape
# Out:
# (5277, 32)

# %%
# ahmed
# pcodes that exist in v4 but not in the OCHA list

# Some are listed under level 3 in v4, when they probably should be in level 4 according to the OCHA list 
# Examples: 
# Southern Tal Arish is in Abu Qalqal (SY020501 not SY020532), 
# Western Sweida is in Hama (SY050100 not SY050181), 
# Zenbaq in in Ein Issa (SY110202 not SY110252)

# Others simply have the wrong pcode (eg. Nabul, which has pcode SY040404, not SY020477 as listed in progres v4
# syria[syria.admin0Pcode.isna()].sample(7)
syria[syria.progres_locationlevel.isin(["Southern Tal Arish", "Abu Qalqal", "Western Sweida", "Nabul"])]
# Out:
#         progres_code                     progres_countryid  \
# 526   21SYR002004077  67C3DB59-6D90-E111-B138-005056AC02A7
# 2004  21SYR002005007  67C3DB59-6D90-E111-B138-005056AC02A7
# 2151  21SYR002005232  67C3DB59-6D90-E111-B138-005056AC02A7
# 3090  21SYR005001181  67C3DB59-6D90-E111-B138-005056AC02A7
#
#      progres_countryidname progres_description_1025 progres_description_1036  \
# 526   Syrian Arab Republic  A_Nabul                  F_Nabul
# 2004  Syrian Arab Republic  A_Abu Qalqal             F_Abu Qalqal
# 2151  Syrian Arab Republic  A_Southern Tal Arish     F_Southern Tal Arish
# 3090  Syrian Arab Republic  A_Western Sweida         F_Western Sweida
#
#      progres_description_3082 progres_filtercode  progres_level  \
# 526   S_Nabul                  21SYR002004077     3.0
# 2004  S_Abu Qalqal             21SYR002005007     3.0
# 2151  S_Southern Tal Arish     21SYR002005232     3.0
# 3090  S_Western Sweida         21SYR005001181     3.0
#
#      progres_locationlevel               progres_locationlevelid  \
# 526   Nabul                 035F097B-628F-EC11-8128-001DD8B71FE5
# 2004  Abu Qalqal            00DEA778-628F-EC11-8120-00155D5CC4A1
# 2151  Southern Tal Arish    7FBA6678-628F-EC11-811F-00155D5CC4A0
# 3090  Western Sweida        7E03B87E-628F-EC11-811F-00155D5CC4A0
#
#       len_pcode_v1  len_pcode_v2 ocha_pcode  len_pcode_ocha admin0Name_en  \
# 526   14.0          14.0          SY020477   8.0             NaN
# 2004  14.0          14.0          SY020507   8.0             NaN
# 2151  14.0          14.0          SY020532   8.0             NaN
# 3090  14.0          14.0          SY050181   8.0             NaN
#
#      admin0Name_ar admin0Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 526   NaN           NaN         NaN           NaN           NaN
# 2004  NaN           NaN         NaN           NaN           NaN
# 2151  NaN           NaN         NaN           NaN           NaN
# 3090  NaN           NaN         NaN           NaN           NaN
#
#      admin2Name_en admin2Name_ar admin2Pcode admin3Name_en admin3Name_ar  \
# 526   NaN           NaN           NaN         NaN           NaN
# 2004  NaN           NaN           NaN         NaN           NaN
# 2151  NaN           NaN           NaN         NaN           NaN
# 3090  NaN           NaN           NaN         NaN           NaN
#
#      admin3Pcode admin3RefName_en LastUpdateDate validOn  validTo  \
# 526   NaN         NaN              NaN            NaN    NaN
# 2004  NaN         NaN              NaN            NaN    NaN
# 2151  NaN         NaN              NaN            NaN    NaN
# 3090  NaN         NaN              NaN            NaN    NaN
#
#      admin2RefName admin1RefName
# 526   NaN           NaN
# 2004  NaN           NaN
# 2151  NaN           NaN
# 3090  NaN           NaN

# %% [markdown]
# ## 2.3 Filtering for 100% matched pcodes: how do names differ between v4 location level table and OCHA table
# If the pcodes matched but the names didn't match

# %% [markdown]
# ### Egypt: Examine table matched with v4 and OCHA codes

# %%
egypt_matched = egypt[(~egypt.admin1Pcode.isna()) & (~egypt.len_pcode_v1.isna())]
eg_1_match = egypt_matched[(egypt_matched.progres_level==1)].progres_locationlevel.unique().tolist()
eg_2_match = egypt_matched[(egypt_matched.progres_level==2)].progres_locationlevel.unique().tolist()
eg_3_match = egypt_matched[(egypt_matched.progres_level==3)].progres_locationlevel.unique().tolist()

# %%
# good ones level 3 : this is fine because location level 3 is not provided in english in the ocha list
egypt_matched[(egypt_matched.progres_level==3) & (egypt_matched.admin3Name_en== egypt_matched.progres_locationlevel)].shape
# Out:
# (0, 49)

# %%
# bad ones level 3: this is fine because location level 3 is not provided in english in the ocha list
egypt_matched[(egypt_matched.progres_level==3) & (egypt_matched.admin3Name_en!= egypt_matched.progres_locationlevel)].shape
# Out:
# (795, 49)

# %%
# good ones level 2: this is fine because location level 3 is not provided in english in the ocha list
egypt_matched[(egypt_matched.progres_level==2) & (egypt_matched.admin2Name_en== egypt_matched.progres_locationlevel)].shape
# Out:
# (342, 49)

# %%
# bad ones level 2: this is fine because location level 3 is not provided in english in the ocha list
egypt_matched[(egypt_matched.progres_level==2) & (egypt_matched.admin2Name_en!= egypt_matched.progres_locationlevel)].shape
# Out:
# (30, 49)

# %%
# ahmed
# bad ones level 2 explore
# this includes Meet Abou Ghaleb (which should actually be listed as Kafr Sad at location 2 level, according to OCHA, but pcodes match so it's okay)
# These are the ones where it doesn't look like there's a match, but when we match by pcodes there is a match
egypt_matched[(egypt_matched.progres_level==2) & (egypt_matched.admin2Name_en!= egypt_matched.progres_locationlevel)][["ocha_pcode", "admin2Name_en", "progres_locationlevel"]]
# Out:
#     ocha_pcode   admin2Name_en progres_locationlevel
# 0    EG1101     Dumyat 1        El Sroo
# 2    EG1102     Dumyat          Izbet Elbarj
# 4    EG1103     Fariskur        Kafr Batikh
# 6    EG1104     Kafr Sad        Meet Abou Ghaleb
# 8    EG1201     El Mansora 1    Al Kordi
# 10   EG1501     Kafr Al-Shaykh  Fouh
# 12   EG1901     Ismailiyya 1    New Alkasaseen
# 14   EG3101     Hurghada 1      Gulf Of Sueiz
# 76   EG0305     Al-Dawahy       Al-Dawahy
# 88   EG2606     Al-Maragha      Al-Maragha
# 129  EG2801     Aswan           Aswan East
# 130  EG2802     Aswan           Aswan West
# 144  EG1401     Banha           Banha City
# 146  EG2201     Bani Swayf      Bani Swayf Qesm
# 165  EG1801     Damanhur        Damanhur City
# 167  EG2608     Dar al-Salam    Dar al-Salam
# 172  EG1505     Disuq           Disuq City
# 188  EG1311     Faqus           Faqus City
# 193  EG2301     Fayyum          Qesm Al Fayyoum
# 200  EG2609     Girga           Girga City
# 202  EG2104     Giza            Giza City
# 213  EG2113     Imbaba          Imbaba Centre
# 219  EG1811     Kafr Al-Dawwar  Kafr Al-Dawwar City
# 238  EG2902     Luxor           Luxor Centre
# 266  EG1212     Mit Ghamr       Mit Ghamr City
# 298  EG1409     Qalyub          Qalyub City
# 307  EG2701     Qina            Qina Centre
# 337  EG1701     Shibin al-Kum   Shibin al-Kum City
# 354  EG0401     Suez            Suez
# 355  EG2601     Suhag           Suhag Qesm

# %%
# NOTE: Zemam Out is now matched (after using the combined table for 1 2 3 instead of just level 3 for cascading)
egypt_matched[egypt_matched.progres_locationlevel=="Zemam Out"]
# Out:
#     progres_code                     progres_countryid progres_countryidname  \
# 385  20EGY001000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 386  20EGY002000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 387  20EGY013000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 388  20EGY014000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 389  20EGY018000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 390  20EGY021000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 391  20EGY022000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 392  20EGY023000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 393  20EGY024000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 394  20EGY028000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 395  20EGY029000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 396  20EGY025000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 397  20EGY026000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 398  20EGY027000  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
#
#     progres_description_1025 progres_description_1036  \
# 385  A_Zemam Out              F_Zemam Out
# 386  A_Zemam Out              F_Zemam Out
# 387  A_Zemam Out              F_Zemam Out
# 388  A_Zemam Out              F_Zemam Out
# 389  A_Zemam Out              F_Zemam Out
# 390  A_Zemam Out              F_Zemam Out
# 391  A_Zemam Out              F_Zemam Out
# 392  A_Zemam Out              F_Zemam Out
# 393  A_Zemam Out              F_Zemam Out
# 394  A_Zemam Out              F_Zemam Out
# 395  A_Zemam Out              F_Zemam Out
# 396  A_Zemam Out              F_Zemam Out
# 397  A_Zemam Out              F_Zemam Out
# 398  A_Zemam Out              F_Zemam Out
#
#     progres_description_3082 progres_filtercode  progres_level  \
# 385  S_Zemam Out              20EGY001000        2.0
# 386  S_Zemam Out              20EGY002000        2.0
# 387  S_Zemam Out              20EGY013000        2.0
# 388  S_Zemam Out              20EGY014000        2.0
# 389  S_Zemam Out              20EGY018000        2.0
# 390  S_Zemam Out              20EGY021000        2.0
# 391  S_Zemam Out              20EGY022000        2.0
# 392  S_Zemam Out              20EGY023000        2.0
# 393  S_Zemam Out              20EGY024000        2.0
# 394  S_Zemam Out              20EGY028000        2.0
# 395  S_Zemam Out              20EGY029000        2.0
# 396  S_Zemam Out              20EGY025000        2.0
# 397  S_Zemam Out              20EGY026000        2.0
# 398  S_Zemam Out              20EGY027000        2.0
#
#     progres_locationlevel               progres_locationlevelid  len_pcode_v1  \
# 385  Zemam Out             74F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 386  Zemam Out             76F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 387  Zemam Out             78F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 388  Zemam Out             7AF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 389  Zemam Out             7CF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 390  Zemam Out             7EF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 391  Zemam Out             80F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 392  Zemam Out             82F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 393  Zemam Out             84F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 394  Zemam Out             86F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 395  Zemam Out             88F3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 396  Zemam Out             8AF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 397  Zemam Out             8CF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
# 398  Zemam Out             8EF3AC72-E114-E911-80DE-001DD8B71FE4  11.0
#
#      len_pcode_v2 ocha_pcode  len_pcode_ocha  OBJECTID *  Shape *  \
# 385  11.0          EG0100     6.0             351.0       Polygon
# 386  11.0          EG0200     6.0             352.0       Polygon
# 387  11.0          EG1300     6.0             353.0       Polygon
# 388  11.0          EG1400     6.0             354.0       Polygon
# 389  11.0          EG1800     6.0             355.0       Polygon
# 390  11.0          EG2100     6.0             356.0       Polygon
# 391  11.0          EG2200     6.0             357.0       Polygon
# 392  11.0          EG2300     6.0             358.0       Polygon
# 393  11.0          EG2400     6.0             359.0       Polygon
# 394  11.0          EG2800     6.0             360.0       Polygon
# 395  11.0          EG2900     6.0             361.0       Polygon
# 396  11.0          EG2500     6.0             362.0       Polygon
# 397  11.0          EG2600     6.0             363.0       Polygon
# 398  11.0          EG2700     6.0             364.0       Polygon
#
#     admin3Name_en admin3Name_ar admin3Pcode admin3RefName admin3AltName1_en  \
# 385  NaN           NaN           NaN         NaN           NaN
# 386  NaN           NaN           NaN         NaN           NaN
# 387  NaN           NaN           NaN         NaN           NaN
# 388  NaN           NaN           NaN         NaN           NaN
# 389  NaN           NaN           NaN         NaN           NaN
# 390  NaN           NaN           NaN         NaN           NaN
# 391  NaN           NaN           NaN         NaN           NaN
# 392  NaN           NaN           NaN         NaN           NaN
# 393  NaN           NaN           NaN         NaN           NaN
# 394  NaN           NaN           NaN         NaN           NaN
# 395  NaN           NaN           NaN         NaN           NaN
# 396  NaN           NaN           NaN         NaN           NaN
# 397  NaN           NaN           NaN         NaN           NaN
# 398  NaN           NaN           NaN         NaN           NaN
#
#     admin3AltName2_en admin3AltName1_ar admin3AltName2_ar admin2Name_en  \
# 385  NaN               NaN               NaN               Zemam Out
# 386  NaN               NaN               NaN               Zemam Out
# 387  NaN               NaN               NaN               Zemam Out
# 388  NaN               NaN               NaN               Zemam Out
# 389  NaN               NaN               NaN               Zemam Out
# 390  NaN               NaN               NaN               Zemam Out
# 391  NaN               NaN               NaN               Zemam Out
# 392  NaN               NaN               NaN               Zemam Out
# 393  NaN               NaN               NaN               Zemam Out
# 394  NaN               NaN               NaN               Zemam Out
# 395  NaN               NaN               NaN               Zemam Out
# 396  NaN               NaN               NaN               Zemam Out
# 397  NaN               NaN               NaN               Zemam Out
# 398  NaN               NaN               NaN               Zemam Out
#
#     admin2Name_ar admin2Pcode admin1Name_en admin1Name_ar admin1Pcode  \
# 385  خارج الزمام   EG0100      Cairo         القاهرة       EG01
# 386  خارج الزمام   EG0200      Alexandria    الاسكندرية    EG02
# 387  خارج الزمام   EG1300      Sharkia       الشرقية       EG13
# 388  خارج الزمام   EG1400      Kalyoubia     القليوبية     EG14
# 389  خارج الزمام   EG1800      Behera        البحيرة       EG18
# 390  خارج الزمام   EG2100      Giza          الجيزة        EG21
# 391  خارج الزمام   EG2200      Beni Suef     بنى سويف      EG22
# 392  خارج الزمام   EG2300      Fayoum        الفيوم        EG23
# 393  خارج الزمام   EG2400      Menia         المنيا        EG24
# 394  خارج الزمام   EG2800      Aswan         أسوان         EG28
# 395  خارج الزمام   EG2900      Luxor         مدينة الأقصر  EG29
# 396  صحراء أسيوط   EG2500      Assiut        أسيوط         EG25
# 397  صحراء سوهاج   EG2600      Suhag         سوهاج         EG26
# 398  صحراء قنا     EG2700      Qena          قنا           EG27
#
#     admin0Name_en admin0Name_ar admin0Pcode       date    validOn validTo  \
# 385  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 386  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 387  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 388  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 389  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 390  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 391  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 392  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 393  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 394  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 395  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 396  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 397  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
# 398  Egypt         مِصر          EG         2006-01-01 2017-04-21  NaN
#
#      Shape_Length  Shape_Area admin2RefName admin2AltName1_en  \
# 385  2.752948      0.142263    Zemam Out     <Null>
# 386  1.559879      0.076360    Zemam Out     <Null>
# 387  1.707252      0.068287    Zemam Out     <Null>
# 388  0.701487      0.011721    Zemam Out     <Null>
# 389  3.028037      0.323599    Zemam Out     <Null>
# 390  16.025570     3.234751    Zemam Out     <Null>
# 391  7.585411      0.833681    Zemam Out     <Null>
# 392  6.920109      0.328431    Zemam Out     <Null>
# 393  12.318939     2.643485    Zemam Out     <Null>
# 394  40.565933     4.981986    Zemam Out     <Null>
# 395  0.934919      0.034017    Zemam Out     <Null>
# 396  7.702932      1.367296    Zemam Out     <Null>
# 397  6.472655      0.762583    Zemam Out     <Null>
# 398  10.281657     1.040645    Zemam Out     <Null>
#
#     admin2AltName2_en admin2AltName1_ar admin2AltName2_ar ValidTo  \
# 385  <Null>            <Null>            <Null>            <Null>
# 386  <Null>            <Null>            <Null>            <Null>
# 387  <Null>            <Null>            <Null>            <Null>
# 388  <Null>            <Null>            <Null>            <Null>
# 389  <Null>            <Null>            <Null>            <Null>
# 390  <Null>            <Null>            <Null>            <Null>
# 391  <Null>            <Null>            <Null>            <Null>
# 392  <Null>            <Null>            <Null>            <Null>
# 393  <Null>            <Null>            <Null>            <Null>
# 394  <Null>            <Null>            <Null>            <Null>
# 395  <Null>            <Null>            <Null>            <Null>
# 396  <Null>            <Null>            <Null>            <Null>
# 397  <Null>            <Null>            <Null>            <Null>
# 398  <Null>            <Null>            <Null>            <Null>
#
#     admin1RefName admin1AltName1_en admin1AltName2_en admin1AltName1_ar  \
# 385  NaN           NaN               NaN               NaN
# 386  NaN           NaN               NaN               NaN
# 387  NaN           NaN               NaN               NaN
# 388  NaN           NaN               NaN               NaN
# 389  NaN           NaN               NaN               NaN
# 390  NaN           NaN               NaN               NaN
# 391  NaN           NaN               NaN               NaN
# 392  NaN           NaN               NaN               NaN
# 393  NaN           NaN               NaN               NaN
# 394  NaN           NaN               NaN               NaN
# 395  NaN           NaN               NaN               NaN
# 396  NaN           NaN               NaN               NaN
# 397  NaN           NaN               NaN               NaN
# 398  NaN           NaN               NaN               NaN
#
#     admin1AltName2_ar
# 385  NaN
# 386  NaN
# 387  NaN
# 388  NaN
# 389  NaN
# 390  NaN
# 391  NaN
# 392  NaN
# 393  NaN
# 394  NaN
# 395  NaN
# 396  NaN
# 397  NaN
# 398  NaN

# %% [markdown]
# ### Egypt: Examine table matched with v4 and OCHA codes

# %%
syria_matched = syria[(~syria.admin1Pcode.isna()) & (~syria.len_pcode_v1.isna())]
sy_1_match = syria_matched[(syria_matched.progres_level==1)].progres_locationlevel.unique().tolist()
sy_2_match = syria_matched[(syria_matched.progres_level==2)].progres_locationlevel.unique().tolist()
sy_3_match = syria_matched[(syria_matched.progres_level==3)].progres_locationlevel.unique().tolist()

# %%
# good level 3
syria_matched[(syria_matched.progres_level==3) & (syria_matched.admin3Name_en== syria_matched.progres_locationlevel)].shape
# Out:
# (2, 32)

# %%
# bad level 3
syria_matched[(syria_matched.progres_level==3) & (syria_matched.admin3Name_en!= syria_matched.progres_locationlevel)].shape
# Out:
# (354, 32)

# %%
# ahmed
# bad level 3 details
# v4 data seems to list locations such as "Abdita" as level 3, when they are actually at a deeper level, i.e. level 4 (and the corresponding pcode in OCHA has a different name)
syria_matched[(syria_matched.progres_level==3) & (syria_matched.admin3Name_en!= syria_matched.progres_locationlevel)][["ocha_pcode", 
                                                                                                                       "admin2Name_en",
                                                                                                                      "admin3Name_en",
                                                                                                                      "progres_locationlevel"]].head(7)
# Out:
#    ocha_pcode admin2Name_en    admin3Name_en progres_locationlevel
# 16  SY020305   Afrin         Sheikh El-Hadid  Upper Marwana
# 17  SY020305   Afrin         Sheikh El-Hadid  Khadraa
# 18  SY020305   Afrin         Sheikh El-Hadid  Ada
# 20  SY020306   Afrin         Ma'btali         Upper Maskeh
# 21  SY020306   Afrin         Ma'btali         Khaldiyet Afrin
# 22  SY020306   Afrin         Ma'btali         Afrin
# 79  SY020401   A'zaz         Aghtrin          Abla

# %%
# Case in point ^^^ 
admin[admin.progres_locationlevel=="Abdita"]
# Out:
#          progres_code                     progres_countryid  \
# 90881  21SYR007005001  67C3DB59-6D90-E111-B138-005056AC02A7
#
#       progres_countryidname progres_description_1025 progres_description_1036  \
# 90881  Syrian Arab Republic  A_Abdita                 F_Abdita
#
#       progres_description_3082 progres_filtercode  progres_level  \
# 90881  S_Abdita                 21SYR007005001     3.0
#
#       progres_locationlevel               progres_locationlevelid  \
# 90881  Abdita                DB03B87E-628F-EC11-811F-00155D5CC4A0
#
#        len_pcode_v1  len_pcode_v2 ocha_pcode  len_pcode_ocha
# 90881  14            14            SY070501   8

# %%
# same as above ^^^
syria_ocha[syria_ocha.admin3Pcode=="SY070501"].head()
# Out:
#           admin0Name_en              admin0Name_ar admin0Pcode admin1Name_en  \
# 1  Syrian Arab Republic  الجمهورية العربية السورية  SY          Idleb
#
#   admin1Name_ar admin1Pcode admin2Name_en admin2Name_ar admin2Pcode  \
# 1  إدلب          SY07        Ariha         أريحا         SY0705
#
#   admin3Name_en admin3Name_ar admin3Pcode admin3RefName_en LastUpdateDate  \
# 1  Ehsem         احسم          SY070501    Ehsem            2016-09-05
#
#       validOn  validTo  progres_level ocha_pcode admin2RefName admin1RefName
# 1  2016-09-05 NaN       3              SY070501   NaN           NaN

# %%
# good level 2
# this is fine because location level 2 is not provided in english in the ocha list
syria_matched[(syria_matched.progres_level==2) & (syria_matched.admin2Name_en== syria_matched.progres_locationlevel)].shape
# Out:
# (62, 32)

# %%
# good level 2
# this is fine because location level 2 is not provided in english in the ocha list
syria_matched[(syria_matched.progres_level==2) & (syria_matched.admin2Name_en== syria_matched.progres_locationlevel)][["ocha_pcode", 
                                                                                                                       "admin2Name_en",
                                                                                                                      # "admin3Name_en",
                                                                                                                      "progres_locationlevel"]].head(7)
# Out:
#      ocha_pcode admin2Name_en progres_locationlevel
# 3855  SY0100     Damascus      Damascus
# 3856  SY0200     Jebel Saman   Jebel Saman
# 3857  SY0202     Al Bab        Al Bab
# 3858  SY0203     Afrin         Afrin
# 3859  SY0204     A'zaz         A'zaz
# 3860  SY0205     Menbij        Menbij
# 3861  SY0206     Ain Al Arab   Ain Al Arab

# %%
# bad level 2
# this is fine because location level 2 is not provided in english in the ocha list
syria_matched[(syria_matched.progres_level==2) & (syria_matched.admin2Name_en!= syria_matched.progres_locationlevel)].shape
# Out:
# (0, 32)

# %%
# bad level 2
syria_matched[(syria_matched.progres_level==2) & (syria_matched.admin2Name_en!= syria_matched.progres_locationlevel)][["ocha_pcode", "admin2Name_en", "progres_locationlevel"]]
# Out:
# Empty DataFrame
# Columns: [ocha_pcode, admin2Name_en, progres_locationlevel]
# Index: []

# %%
# bad level 1
syria_matched[(syria_matched.progres_level==1) & (syria_matched.admin1Name_en!= syria_matched.progres_locationlevel)]
# Out:
# Empty DataFrame
# Columns: [progres_code, progres_countryid, progres_countryidname, progres_description_1025, progres_description_1036, progres_description_3082, progres_filtercode, progres_level, progres_locationlevel, progres_locationlevelid, len_pcode_v1, len_pcode_v2, ocha_pcode, len_pcode_ocha, admin0Name_en, admin0Name_ar, admin0Pcode, admin1Name_en, admin1Name_ar, admin1Pcode, admin2Name_en, admin2Name_ar, admin2Pcode, admin3Name_en, admin3Name_ar, admin3Pcode, admin3RefName_en, LastUpdateDate, validOn, validTo, admin2RefName, admin1RefName]
# Index: []

# %%
# bad level 1
syria_matched[(syria_matched.progres_level==1) & (syria_matched.admin1Name_en== syria_matched.progres_locationlevel)].shape
# Out:
# (14, 32)

# %%
syria.columns
# Out:
# Index(['progres_code', 'progres_countryid', 'progres_countryidname',
#        'progres_description_1025', 'progres_description_1036',
#        'progres_description_3082', 'progres_filtercode', 'progres_level',
#        'progres_locationlevel', 'progres_locationlevelid', 'len_pcode_v1',
#        'len_pcode_v2', 'ocha_pcode', 'len_pcode_ocha', 'admin0Name_en',
#        'admin0Name_ar', 'admin0Pcode', 'admin1Name_en', 'admin1Name_ar',
#        'admin1Pcode', 'admin2Name_en', 'admin2Name_ar', 'admin2Pcode',
#        'admin3Name_en', 'admin3Name_ar', 'admin3Pcode', 'admin3RefName_en',
#        'LastUpdateDate', 'validOn', 'validTo', 'admin2RefName',
#        'admin1RefName'],
#       dtype='object')

# %% [markdown]
# ## Save egypt and syria data

# %%
SERVER = ip_of_server
DATABASE = 'QualityCheck_Egypt'
DRIVER = 'SQL Server'
USERNAME = uap.split(',')[0]
PASSWORD = uap.split(',')[1]
DATABASE_CONNECTION = f'mssql://{USERNAME}:{PASSWORD}@{SERVER}/{DATABASE}?driver={DRIVER}'

# %%
engine = sqlalchemy.create_engine(DATABASE_CONNECTION)
connection = engine.connect()

# %%
egypt= egypt.drop(columns=["validTo", "ValidTo"])
# syria= syria.drop(columns=["validTo", "ValidTo"])

# %%
egypt.head()
# Out:
#   progres_code                     progres_countryid progres_countryidname  \
# 0  20EGY011a01  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 1  20EGY011001  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 2  20EGY011a02  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 3  20EGY011002  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
# 4  20EGY011a03  CFC1DB59-6D90-E111-B138-005056AC02A7  Egypt
#
#   progres_description_1025 progres_description_1036 progres_description_3082  \
# 0  A_El Sroo                F_El Sroo                S_El Sroo
# 1  A_Dumyat 1               F_Dumyat 1               S_Dumyat 1
# 2  A_Izbet Elbarj           F_Izbet Elbarj           S_Izbet Elbarj
# 3  A_Dumyat                 F_Dumyat                 S_Dumyat
# 4  A_Kafr Batikh            F_Kafr Batikh            S_Kafr Batikh
#
#   progres_filtercode  progres_level progres_locationlevel  \
# 0  20EGY011a01        2.0            El Sroo
# 1  20EGY011001        2.0            Dumyat 1
# 2  20EGY011a02        2.0            Izbet Elbarj
# 3  20EGY011002        2.0            Dumyat
# 4  20EGY011a03        2.0            Kafr Batikh
#
#                 progres_locationlevelid  len_pcode_v1  len_pcode_v2  \
# 0  9566FBCA-B8E7-EB11-810A-00155D5CC459  11.0          11.0
# 1  C0F1AC72-E114-E911-80DE-001DD8B71FE4  11.0          11.0
# 2  9766FBCA-B8E7-EB11-810A-00155D5CC459  11.0          11.0
# 3  BEF1AC72-E114-E911-80DE-001DD8B71FE4  11.0          11.0
# 4  9866FBCA-B8E7-EB11-810A-00155D5CC459  11.0          11.0
#
#   ocha_pcode  len_pcode_ocha  OBJECTID *  Shape * admin3Name_en admin3Name_ar  \
# 0  EG1101     6.0             132.0       Polygon  NaN           NaN
# 1  EG1101     6.0             132.0       Polygon  NaN           NaN
# 2  EG1102     6.0             131.0       Polygon  NaN           NaN
# 3  EG1102     6.0             131.0       Polygon  NaN           NaN
# 4  EG1103     6.0             150.0       Polygon  NaN           NaN
#
#   admin3Pcode admin3RefName admin3AltName1_en admin3AltName2_en  \
# 0  NaN         NaN           NaN               NaN
# 1  NaN         NaN           NaN               NaN
# 2  NaN         NaN           NaN               NaN
# 3  NaN         NaN           NaN               NaN
# 4  NaN         NaN           NaN               NaN
#
#   admin3AltName1_ar admin3AltName2_ar admin2Name_en  admin2Name_ar  \
# 0  NaN               NaN               Dumyat 1      قسم أول دمياط
# 1  NaN               NaN               Dumyat 1      قسم أول دمياط
# 2  NaN               NaN               Dumyat        مركز دمياط
# 3  NaN               NaN               Dumyat        مركز دمياط
# 4  NaN               NaN               Fariskur      مركز فارسكور
#
#   admin2Pcode admin1Name_en admin1Name_ar admin1Pcode admin0Name_en  \
# 0  EG1101      Damietta      دمياط         EG11        Egypt
# 1  EG1101      Damietta      دمياط         EG11        Egypt
# 2  EG1102      Damietta      دمياط         EG11        Egypt
# 3  EG1102      Damietta      دمياط         EG11        Egypt
# 4  EG1103      Damietta      دمياط         EG11        Egypt
#
#   admin0Name_ar admin0Pcode       date    validOn  Shape_Length  Shape_Area  \
# 0  مِصر          EG         2006-01-01 2017-04-21  0.127185      0.000707
# 1  مِصر          EG         2006-01-01 2017-04-21  0.127185      0.000707
# 2  مِصر          EG         2006-01-01 2017-04-21  2.218709      0.018665
# 3  مِصر          EG         2006-01-01 2017-04-21  2.218709      0.018665
# 4  مِصر          EG         2006-01-01 2017-04-21  0.627702      0.010760
#
#   admin2RefName admin2AltName1_en admin2AltName2_en admin2AltName1_ar  \
# 0  Dumyat 1      <Null>            <Null>            <Null>
# 1  Dumyat 1      <Null>            <Null>            <Null>
# 2  Dumyat        <Null>            <Null>            <Null>
# 3  Dumyat        <Null>            <Null>            <Null>
# 4  Fariskur      <Null>            <Null>            <Null>
#
#   admin2AltName2_ar admin1RefName admin1AltName1_en admin1AltName2_en  \
# 0  <Null>            NaN           NaN               NaN
# 1  <Null>            NaN           NaN               NaN
# 2  <Null>            NaN           NaN               NaN
# 3  <Null>            NaN           NaN               NaN
# 4  <Null>            NaN           NaN               NaN
#
#   admin1AltName1_ar admin1AltName2_ar
# 0  NaN               NaN
# 1  NaN               NaN
# 2  NaN               NaN
# 3  NaN               NaN
# 4  NaN               NaN

# %%
rename_columns = {  "ocha_pcode" : "ocha_v4_pcode",
                    'admin3Name_en' : 'admin3_name_ocha', 
                    'admin3Name_ar' : 'admin3_name_ar_ocha',
                    'admin3Pcode' : 'admin3_pcode_ocha', 
                    'admin2Name_en' : 'admin2_name_ocha', 
                    'admin2Name_ar' : 'admin2_name_ar_ocha',
                    'admin2Pcode' : 'admin2_pcode_ocha',
                    'admin1Name_en' : 'admin1_name_ocha',
                    'admin1Name_ar' : 'admin1_name_ar_ocha',
                    'admin1Pcode' : 'admin1_pcode_ocha', 
                    'admin0Name_en' : 'admin0_name_ocha',
                    'admin0Name_ar' : 'admin0_name_ar_ocha',
                    'admin0Pcode' : 'admi0_pcode_ocha'
                  }
ocha_columns = list(rename_columns.values())
columns_to_keep = [ "progres_countryidname", "progres_locationlevel", "progres_level", "progres_code"] + ocha_columns

# %%
egypt_renamed = egypt.rename(columns = rename_columns)
egypt_renamed = egypt_renamed[columns_to_keep]

syria_renamed = syria.rename(columns = rename_columns)
syria_renamed = syria_renamed[columns_to_keep]

# %%
egypt_renamed.head()
# Out:
#   progres_countryidname progres_locationlevel  progres_level progres_code  \
# 0  Egypt                 El Sroo               2.0            20EGY011a01
# 1  Egypt                 Dumyat 1              2.0            20EGY011001
# 2  Egypt                 Izbet Elbarj          2.0            20EGY011a02
# 3  Egypt                 Dumyat                2.0            20EGY011002
# 4  Egypt                 Kafr Batikh           2.0            20EGY011a03
#
#   ocha_v4_pcode admin3_name_ocha admin3_name_ar_ocha admin3_pcode_ocha  \
# 0  EG1101        NaN              NaN                 NaN
# 1  EG1101        NaN              NaN                 NaN
# 2  EG1102        NaN              NaN                 NaN
# 3  EG1102        NaN              NaN                 NaN
# 4  EG1103        NaN              NaN                 NaN
#
#   admin2_name_ocha admin2_name_ar_ocha admin2_pcode_ocha admin1_name_ocha  \
# 0  Dumyat 1         قسم أول دمياط       EG1101            Damietta
# 1  Dumyat 1         قسم أول دمياط       EG1101            Damietta
# 2  Dumyat           مركز دمياط          EG1102            Damietta
# 3  Dumyat           مركز دمياط          EG1102            Damietta
# 4  Fariskur         مركز فارسكور        EG1103            Damietta
#
#   admin1_name_ar_ocha admin1_pcode_ocha admin0_name_ocha admin0_name_ar_ocha  \
# 0  دمياط               EG11              Egypt            مِصر
# 1  دمياط               EG11              Egypt            مِصر
# 2  دمياط               EG11              Egypt            مِصر
# 3  دمياط               EG11              Egypt            مِصر
# 4  دمياط               EG11              Egypt            مِصر
#
#   admi0_pcode_ocha
# 0  EG
# 1  EG
# 2  EG
# 3  EG
# 4  EG

# %%
syria_renamed.head()
# Out:
#   progres_countryidname progres_locationlevel  progres_level progres_code  \
# 0  Syrian Arab Republic  Damascus              1.0            21SYR001
# 1  Syrian Arab Republic  Aleppo                1.0            21SYR002
# 2  Syrian Arab Republic  Rural Damascus        1.0            21SYR003
# 3  Syrian Arab Republic  Homs                  1.0            21SYR004
# 4  Syrian Arab Republic  Hama                  1.0            21SYR005
#
#   ocha_v4_pcode admin3_name_ocha admin3_name_ar_ocha admin3_pcode_ocha  \
# 0  SY01          NaN              NaN                 NaN
# 1  SY02          NaN              NaN                 NaN
# 2  SY03          NaN              NaN                 NaN
# 3  SY04          NaN              NaN                 NaN
# 4  SY05          NaN              NaN                 NaN
#
#   admin2_name_ocha admin2_name_ar_ocha admin2_pcode_ocha admin1_name_ocha  \
# 0  NaN              NaN                 NaN               Damascus
# 1  NaN              NaN                 NaN               Aleppo
# 2  NaN              NaN                 NaN               Rural Damascus
# 3  NaN              NaN                 NaN               Homs
# 4  NaN              NaN                 NaN               Hama
#
#   admin1_name_ar_ocha admin1_pcode_ocha      admin0_name_ocha  \
# 0  دمشق                SY01              Syrian Arab Republic
# 1  حلب                 SY02              Syrian Arab Republic
# 2  ريف دمشق            SY03              Syrian Arab Republic
# 3  حمص                 SY04              Syrian Arab Republic
# 4  حماة                SY05              Syrian Arab Republic
#
#          admin0_name_ar_ocha admi0_pcode_ocha
# 0  الجمهورية العربية السورية  SY
# 1  الجمهورية العربية السورية  SY
# 2  الجمهورية العربية السورية  SY
# 3  الجمهورية العربية السورية  SY
# 4  الجمهورية العربية السورية  SY

# %%
# # write the DataFrame to a table in the sql database
# egypt_renamed.to_sql("Egypt_locations", 
#                 engine, 
#                 # schema="dbo",
#                 if_exists='replace', # or append
#                 index=False
#                )

# %%
# # write the DataFrame to a table in the sql database
# syria_renamed.to_sql("Syria_locations", 
#                 engine, 
#                 # schema="dbo",
#                 if_exists='replace', # or append
#                 index=False
#                )

# %%
# syria_renamed.to_csv("Syria_matched_locations.csv", encoding = 'utf-8')
# egypt_renamed.to_csv("Egypt_matched_locations.csv", encoding = 'utf-8')
